# %%
#!/usr/bin/env python3
# Download the 56 zip files in Images_png in batches
import urllib.request
import tarfile
import numpy as np

# %%
# URLs for the zip files
links = [
    'https://nihcc.box.com/shared/static/vfk49d74nhbxq3nqjg0900w5nvkorp5c.gz',
    'https://nihcc.box.com/shared/static/i28rlmbvmfjbl8p2n3ril0pptcmcu9d1.gz',
    'https://nihcc.box.com/shared/static/f1t00wrtdk94satdfb9olcolqx20z2jp.gz',
	'https://nihcc.box.com/shared/static/0aowwzs5lhjrceb3qp67ahp0rd1l1etg.gz',
    'https://nihcc.box.com/shared/static/v5e3goj22zr6h8tzualxfsqlqaygfbsn.gz',
	'https://nihcc.box.com/shared/static/asi7ikud9jwnkrnkj99jnpfkjdes7l6l.gz',
	'https://nihcc.box.com/shared/static/jn1b4mw4n6lnh74ovmcjb8y48h8xj07n.gz',
    'https://nihcc.box.com/shared/static/tvpxmn7qyrgl0w8wfh9kqfjskv6nmm1j.gz',
	'https://nihcc.box.com/shared/static/upyy3ml7qdumlgk2rfcvlb9k6gvqq2pj.gz',
	'https://nihcc.box.com/shared/static/l6nilvfa9cg3s28tqv1qc1olm3gnz54p.gz',
	'https://nihcc.box.com/shared/static/hhq8fkdgvcari67vfhs7ppg2w6ni4jze.gz',
	'https://nihcc.box.com/shared/static/ioqwiy20ihqwyr8pf4c24eazhh281pbu.gz'
]

# %%
# Download the compressed image files
for idx, link in enumerate(links):
    filename = 'Dataset/images_%02d.tar.gz' % (idx+1)
    print('downloading '+filename+'...')
    urllib.request.urlretrieve(link, filename)  # download the zip file

print("Download complete. Please check the checksums")

# %%
# Extracting all images from the compressed files
for idx, link in enumerate(links[1:]):
    filename = 'Dataset/images_%02d.tar.gz' % (idx+2)
    print('extracting '+filename+'...')
    tf = tarfile.open(filename, 'r')
    tf.extractall('Dataset')

print("Extracting complete. All images are now under Dataset/images folder.")
# Out:
# extracting Dataset/images_02.tar.gz...
# extracting Dataset/images_03.tar.gz...
# extracting Dataset/images_04.tar.gz...
# extracting Dataset/images_05.tar.gz...
# extracting Dataset/images_06.tar.gz...
# extracting Dataset/images_07.tar.gz...
# extracting Dataset/images_08.tar.gz...
# extracting Dataset/images_09.tar.gz...
# extracting Dataset/images_10.tar.gz...
# extracting Dataset/images_11.tar.gz...
# extracting Dataset/images_12.tar.gz...
# Extracting complete. All images are now under Dataset/images folder.

# %%
# Show a random image
# %matplotlib inline
import numpy as np                     
import matplotlib.pyplot as plt
import os
import cv2 as cv
import random

# %%
def load_image(path):
    for img in os.listdir(path):
        print('Image name =',img)
        image = cv.imread(os.path.join(path, img))
        break
        
    return image

# %%
im_path = 'Dataset/images'
img = load_image(im_path)
# Out:
# Image name = 00015803_007.png

# %%
plt.imshow(img, cmap='gray')
plt.colorbar()
plt.title('Raw Chest X Ray Image')
print(f"The dimensions are {img.shape[0]} pixels height and {img.shape[1]} pixels width")
print(f"The maximum pixel value is {img.max():.4f}")
print(f"The minimum pixel value is {img.min():.4f}")
print(f"The mean value of the pixels is {img.mean():.4f}")
print(f"The standard deviation is {img.std():.4f}")
# Out:
# The dimensions are 1024 pixels height and 1024 pixels width
# The maximum pixel value is 255.0000
# The minimum pixel value is 0.0000
# The mean value of the pixels is 113.7148
# The standard deviation is 58.7766

# %%
img.shape
# Out:
# (1024, 1024, 3)

# %%
sum(img[:,:,0] == img[:,:,1])
# Out:
# array([1024, 1024, 1024, ..., 1024, 1024, 1024])
